# %% [markdown]
# ## Question 1
#
# Run it to test that it's working locally:
#
# Here <value> is the probability of getting a credit card. You need to choose the right one.

# %%
# !python q6_test.py
# Out:
# {'get_credit': True, 'get_credit_probability': 0.726936946355423}

# %% [markdown]
# The value is **0.7269**

# %% [markdown]
# ## Question 2
#
# What's the version of kind that you have?
#
# Use kind --version to find out.

# %%
# !kind --version
# Out:
# kind version 0.20.0

# %% [markdown]
# The version is **0.20.0**

# %% [markdown]
# ## Question 3
# Now let's test if everything works. Use kubectl to get the list of running services.
#
# What's CLUSTER-IP of the service that is already running there?

# %%
# !kubectl get service
# Out:
# NAME         TYPE        CLUSTER-IP   EXTERNAL-IP   PORT(S)   AGE
# kubernetes   ClusterIP   10.96.0.1    <none>        443/TCP   119s

# %% [markdown]
# The CLUSTER IP is **10.96.0.1**

# %% [markdown]
# ## Question 4
# To be able to use the docker image we previously created (zoomcamp-model:hw10), we need to register it with kind.
#
# What's the command we need to run for that?

# %% [markdown]
# **kind load docker-image**

# %% [markdown]
# ## Question 5
#
# Replace Image, Memory, CPU, Port with the correct values.
#
# What is the value for Port?
#
# Apply this deployment using the appropriate command and get a list of running Pods. You can see one running Pod.

# %% [markdown]
# The port value is **9696** since we service inside our docker served in 9696 port

# %% [markdown]
# ## Question 6
#
# Fill it in. What do we need to write instead of ??? ?
#
# Apply this config file.

# %% [markdown]
# The selector app is **credit** since we want the service to propagate the request from user to "credit" pod

# %% [markdown]
# ## Question 7
# Run kubectl get hpa credit-hpa --watch command to monitor how the autoscaler performs. Within a minute or so, you should see the higher CPU load; and then - more replicas. What was the maximum amount of the replicas during this test?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the maximum amoount replicas during test is **2**
